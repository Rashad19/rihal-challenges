# %% [markdown]
# # Rihal Data Science Challenge
#
# You are allowed to use any method in reading, loading, transforming the data. Additionally, you can use any model to predict the price of used cars.
#
# **Make sure** you explain your approach at each step, and to evaluate your model. Finally, you must show the Mean Asbolute Error from your model's predictions when compared with the test dataset's prices.
#
# ---------------------------

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns

pd.options.display.max_columns = 110

# %% [markdown]
# ## Read Data

# %%
df_train = pd.read_csv('data_train.csv')
df_test = pd.read_csv('data_test.csv')

# %%
display(df_train.head())
display(df_test.head())
# Out:
#   manufacturer_name transmission  color  odometer_value  year_produced  \
# 0        Volkswagen    automatic  black          130000           2016
# 1           Renault       manual  brown          149000           2012
# 2               Kia    automatic  brown          110000           2014
# 3              Opel    automatic  other          255100           2007
# 4             Mazda       manual   blue          650000           1999
#
#   engine_fuel engine_type  engine_capacity  body_type  has_warranty ownership  \
# 0      diesel      diesel              1.6  universal         False     owned
# 1    gasoline    gasoline              1.6      sedan         False     owned
# 2    gasoline    gasoline              1.6  hatchback         False     owned
# 3    gasoline    gasoline              1.8  hatchback         False     owned
# 4    gasoline    gasoline              2.0      sedan         False     owned
#
# ...

# %% [markdown]
# ## Number of unique values for each column

# %%
# we need to check the number of unique values in each column
# just to have an idea of the structure of the data.
df_train.nunique()
# Out:
# manufacturer_name          55
# transmission                2
# color                      12
# odometer_value           5455
# year_produced              63
# engine_fuel                 6
# engine_type                 3
# engine_capacity            61
# body_type                  12
# has_warranty                2
# ownership                   3
# type_of_drive               3
# is_exchangeable             2
# number_of_photos           60
# number_of_maintenance     365
# duration_listed           760
# price_usd                2495
# dtype: int64

# %%
df_test.nunique()
# Out:
# manufacturer_name          55
# transmission                2
# color                      12
# odometer_value           3915
# year_produced              63
# engine_fuel                 5
# engine_type                 3
# engine_capacity            59
# body_type                  12
# has_warranty                2
# ownership                   3
# type_of_drive               3
# is_exchangeable             2
# number_of_photos           54
# number_of_maintenance     311
# duration_listed           654
# price_usd                2034
# dtype: int64

# %% [markdown]
# ### Categorical variables to Numeric variables

# %%
# first we transform the binary independent variable
# that is, has_warranty, is_exchangeable and transmission
# we do this by creating dummy variables for each value

dummy_warranty = pd.get_dummies(df_train['has_warranty'])

# %%
display(dummy_warranty.head())
# Out:
#    False  True
# 0      1     0
# 1      1     0
# 2      1     0
# 3      1     0
# 4      1     0

# %%
df1 = df_train
df1.drop(['has_warranty'], axis = 1, inplace = True)

display(df1)

dummy_warranty.drop(['True'], axis=1, inplace = True)
# dummy_warranty.rename(columns={'True: yes_warranty'})
# Out:
#       manufacturer_name transmission  color  odometer_value  year_produced  \
# 0            Volkswagen    automatic  black          130000           2016
# 1               Renault       manual  brown          149000           2012
# 2                   Kia    automatic  brown          110000           2014
# 3                  Opel    automatic  other          255100           2007
# 4                 Mazda       manual   blue          650000           1999
# ...                 ...          ...    ...             ...            ...
# 49995              Opel       manual  white          380000           1996
# 49996        Volkswagen       manual  green          311213           1994
# 49997              Fiat       manual    red          250000           1999
# 49998               BMW    automatic   grey          615000           1998
# 49999             Volvo    automatic  other          485000           2002
#
# ...
